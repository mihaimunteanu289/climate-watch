# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import datetime

pd.set_option('display.max_columns', None)
# Extract today datetime including day, month, year, hour etc.
now = datetime.datetime.now()

from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import davies_bouldin_score
from sklearn.cluster import KMeans

# %%
df_set = pd.read_excel('set_complet_precip.xlsx')

# %%
df = df_set.copy()

# %%
df = df.dropna().reset_index(drop=True)

# %%
df.fillna(0, inplace=True)

# %%
df.set_index(['date', 'region', 'County', 'phenomena'], inplace=True)

# %%
# Create a scaled object
scaler = StandardScaler()
# Create the normalized dataframe
df_scaled = pd.DataFrame(data=scaler.fit_transform(df), columns=df.columns, index=df.index)

# %%
# Create a list with numbers from 1 to 10
number_of_clusters = list(range(1, 11))
# SSE Metric list
sum_of_squared_distance = []

for cluster in number_of_clusters:
    kmeans = KMeans(n_clusters=cluster, n_init=10, random_state=42)
    kmeans.fit(df_scaled)
    sum_of_squared_distance.append(kmeans.inertia_)

# %%
sns.set_theme(style='whitegrid')
sns.set(rc={'figure.figsize':(13,7)})

plt.plot(number_of_clusters, sum_of_squared_distance, 'go--')
plt.xlabel('Number of Clusters', fontsize=13)
plt.ylabel('Within Cluster Sum of squares', fontsize=13)
plt.title('Elbow Curve to find optimum K', fontsize=15)
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(15,8))
for i in list(range(2, 8)):
    # Create KMeans instance for different number of clusters
    km = KMeans(n_clusters=i, n_init=10, random_state=42)
    q, mod = divmod(i, 2)
    # Create SilhouetteVisualizer instance with KMeans instance
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(df_scaled)

# %%
number_of_clusters = list(range(2,11))
results  = {}

for i in number_of_clusters:
    kmeans = KMeans(n_clusters=i, n_init=10, random_state=42)
    labels = kmeans.fit_predict(df_scaled)
    db_index = davies_bouldin_score(df_scaled, labels)
    results.update({i: db_index})

# %%
sns.set_theme(style='whitegrid')
sns.set(rc={'figure.figsize':(13,7)})

plt.plot(list(results.keys()), list(results.values()), 'go--')
plt.xlabel('Number of Clusters', fontsize=13)
plt.ylabel('Davies-Bouldin Index', fontsize=13)
plt.title('Davies-Bouldin Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
# Create a KMeans object having 4 clusters and being named kmeans
kmeans = KMeans(n_clusters=4, n_init=10, random_state=42).fit_predict(df_scaled)
# The below command has been used for visualization purpose only. We want to have a look at the created clusters and
# the frequency from each cluster
unique, counts = np.unique(kmeans, return_counts=True)
# If we have 2 iterables (e.g. lists or tuples) of equal length and need to create a dictionary, we have
# to use the zip() function
print(f"Created clusters - {dict(zip(unique, counts))}")

# Create a dataframe for kmeans object
clusters = pd.DataFrame({'Clusters' : kmeans})
df_clusters = pd.concat([df.reset_index(), clusters], axis=1)
# Out:
# Created clusters - {0: 1688, 1: 803, 2: 1555, 3: 670}

# %%
df_clusters
# Out:
#            date    region County  \
# 0    2015-02-09   Moldova     IS
# 1    2015-02-10   Moldova     IS
# 2    2015-02-11   Moldova     IS
# 3    2015-02-13   Moldova     IS
# 4    2015-02-14   Moldova     IS
# ...         ...       ...    ...
# 4711 2023-08-05  Muntenia      B
# 4712 2023-08-06  Muntenia      B
# 4713 2023-08-07  Muntenia      B
# 4714 2023-08-08  Muntenia      B
# 4715 2023-08-09  Muntenia      B
#
#                                               phenomena  \
# 0                                          ['Ninsoare']
# 1                ['Ninsoare slaba', 'Fulguieli', 'Ger']
# 2                                  ['Ninsoare', 'Vânt']
# 3                                               ['Ger']
# 4                                               ['Ger']
# ...                                                 ...
# 4711  ['Canicula', 'Furtună', 'Averse', 'Grindina', ...
# 4712       ['Averse', 'Furtună', 'Vijelie', 'Canicula']
# 4713                                         ['Ploaie']
# 4714                        ['Ploaie', 'Secetă', 'Ger']
# 4715                                       ['Canicula']
#
#       42i - NO2_Valoare [µg/m³]  43i - SO2_Valoare [µg/m³]  \
# 0                      2.760000                   2.490000
# 1                      3.750000                   5.860000
# 2                      2.740000                   6.120000
# 3                      5.750000                   6.930000
# 4                      5.170000                   5.630000
# ...                         ...                        ...
# 4711                  12.554286                   5.057500
# 4712                  12.752857                   4.825000
# 4713                  12.577778                   5.503333
# 4714                  18.200000                   4.943333
# 4715                  25.912222                   5.130000
#
#       48i - CO_Valoare [mg/m³]  GRAV. 10 - PM 10_Valoare [µg/m³]  \
# 0                     0.310000                         12.217500
# 1                     0.500000                         22.097500
# 2                     0.410000                         32.356667
# 3                     1.210000                         64.120000
# 4                     0.930000                         57.800000
# ...                        ...                               ...
# 4711                  0.423333                         26.654000
# 4712                  0.450000                         24.078000
# 4713                  0.390000                         25.906000
# 4714                  0.402500                         24.974000
# 4715                  0.420000                         22.690000
#
#       GRAV. 2.5 - PM 2.5_Valoare [µg/m³]  \
# 0                              12.390000
# 1                              18.840000
# 2                              20.650000
# 3                              77.540000
# 4                              62.500000
# ...                                  ...
# 4711                           16.433333
# 4712                           13.473333
# 4713                           15.753333
# 4714                           13.526667
# 4715                            9.015000
#
#       MTX - Presiunea aerului_Valoare [mbar]  \
# 0                                 999.400000
# 1                                1006.500000
# 2                                1012.950000
# 3                                1013.700000
# 4                                1010.450000
# ...                                      ...
# 4711                              996.728571
# 4712                              989.657143
# 4713                              995.425000
# 4714                             1002.725000
# 4715                             1005.700000
#
#       MTX - Temperatura aer_Valoare [°C]  \
# 0                              -1.060000
# 1                              -2.893333
# 2                              -3.193333
# 3                               1.400000
# 4                               2.303333
# ...                                  ...
# 4711                           28.891429
# 4712                           25.441429
# 4713                           24.571250
# 4714                           20.047500
# 4715                           21.606250
#
#       MTX - Umiditate relativa_Valoare [%]  water_average  Clusters
# 0                                84.000000     472.500000         2
# 1                                77.500000     470.500000         2
# 2                                72.000000     463.833333         2
# 3                                78.000000     451.833333         3
# 4                                81.500000     437.333333         3
# ...                                    ...            ...       ...
# 4711                             54.285714     160.166667         0
# 4712                             69.000000     167.166667         0
# 4713                             49.375000     170.500000         0
# 4714                             71.750000     173.333333         0
# 4715                             56.875000     174.000000         0
#
# [4716 rows x 14 columns]

# %%
df_clusters[df_clusters['Clusters'] == 0]['phenomena']
# Out:
# 39                                             ['Ploaie']
# 43               ['Cer senin', 'Temperaturi in crestere']
# 44                                           ['Canicula']
# 45                                             ['Fulger']
# 46                                ['Furtună', 'Grindina']
#                               ...
# 4711    ['Canicula', 'Furtună', 'Averse', 'Grindina', ...
# 4712         ['Averse', 'Furtună', 'Vijelie', 'Canicula']
# 4713                                           ['Ploaie']
# 4714                          ['Ploaie', 'Secetă', 'Ger']
# 4715                                         ['Canicula']
# Name: phenomena, Length: 1688, dtype: object

# %%
df_clusters[df_clusters['Clusters'] == 0]['phenomena']
